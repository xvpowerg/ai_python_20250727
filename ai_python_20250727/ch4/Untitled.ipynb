# %% [markdown]
# # 作業：支出最大與最小

# %%
priceList = []
priceSum = 0
for i in range(1,5):
    p = int(input(f"請輸入{i}個月的支出金額"))
    priceSum += p
    priceList.append(p)
priceList.sort()
print(f"max:{priceList[-1]}")
print(f"min:{priceList[0]}")
print(priceSum)
print(priceList)
# Out:
# 請輸入1個月的支出金額 1000
# 請輸入2個月的支出金額 3000
# 請輸入3個月的支出金額 4000
# 請輸入4個月的支出金額 6000
# max:6000
# min:1000
# 14000
# [1000, 3000, 4000, 6000]

# %% [markdown]
# ## 常見例外
# ![image.png](attachment:ddaf0e4a-7785-421b-aec1-f4d7f013d85a.png)

# %%
num1 = 10
num2 = 0
print("Start")
print(num1 / num2)
print("End")
# Out:
# Start
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 4
#       2 num2 = 0
#       3 print("Start")
# ----> 4 print(num1 / num2)
#       5 print("End")
#
# ZeroDivisionError: division by zero

# %%
num1 = 10
num2 = 0
print("Start")
try:
    print(num1 / num2)
except:
    print("錯誤發生")

print("End")
# Out:
# Start
# 錯誤發生
# End

# %%
num1 = 10
num2 = 0
nums = [1,2,3,4]
print("Start")
myIndex = 99

try:
    print(num1 / num2)
    print(nums[myIndex])
except IndexError:
    print(f"List index 錯誤發生{myIndex}")
except ZeroDivisionError as ex:
    print(type(ex))
    print(f"分母不可為零{ex}")
print("End")
# Out:
# Start
# <class 'ZeroDivisionError'>
# 分母不可為零division by zero
# End

# %%
nameList = ["Ken","Vivin","Joy","Iris"]
while True:
    try:
        print(nameList.pop())
    except:
       break
# Out:
# Iris
# Joy
# Vivin
# Ken

# %% [markdown]
# ## 使用raise拋例外

# %%
# 傳入一個socre 希望檢測成績正確性 正確範圍是0~100 不是0~100顯示錯誤的成績　　是　顯示輸入的成績
def testScore(score):
    if score > 100 or score < 0:
        #print("錯誤的成績")
        raise OverflowError("錯誤的成績")
    else:
        print(score)
        
print("Start")        
testScore(-50)
print("End")
# Out:
# Start
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[16], line 10
#       7         print(score)
#       9 print("Start")
# ---> 10 testScore(-50)
#      11 print("End")
#
# Cell In[16], line 5, in testScore(score)
#       2 def testScore(score):
#       3     if score > 100 or score < 0:
#       4         #print("錯誤的成績")
# ----> 5         raise OverflowError("錯誤的成績")
#       6     else:
#       7         print(score)
#
# OverflowError: 錯誤的成績

# %% [markdown]
# ![image.png](attachment:975cac0d-f01c-430f-a3cd-bcd116bc2b7b.png)
# ![image.png](attachment:c7b1f588-453f-44c3-befd-7c8f0567c021.png)

# %%
import re
s = "Tim's phone numbers are 12345-41521 and 78963-85214"
match = re.findall(r"\d",s)
print(match)
# Out:
# ['1', '2', '3', '4', '5', '4', '1', '5', '2', '1', '7', '8', '9', '6', '3', '8', '5', '2', '1', '4']

# %%
path = r"c:\myfile\new"
print(path)
# Out:
# c:\myfile\new

# %% [markdown]
# ![image.png](attachment:89c6b310-1202-4b20-b444-d25a078967eb.png)

# %%
s = "Tim's phone numbers are 12345-41521 and 78963-85214"
match = re.findall(r"\d{5}",s)
print(match)
# Out:
# ['12345', '41521', '78963', '85214']

# %% [markdown]
# ![image.png](attachment:8fd936e9-f625-4983-bda2-ace0e14445e8.png)

# %%
import  re
s="Python was conceived in the late 1980s by Guido van Rossum aaaaaaaa"
match = re.findall(r"[a-t]",s)
print(match)
match = re.findall(r"[a-t]{2}",s)
print(match)
match = re.findall(r"[a-t]{3,6}",s)
print(match)
match = re.findall(r"[a-t]{4,}",s)
print(match)
# Out:
# ['t', 'h', 'o', 'n', 'a', 's', 'c', 'o', 'n', 'c', 'e', 'i', 'e', 'd', 'i', 'n', 't', 'h', 'e', 'l', 'a', 't', 'e', 's', 'b', 'i', 'd', 'o', 'a', 'n', 'o', 's', 's', 'm', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']
# ['th', 'on', 'as', 'co', 'nc', 'ei', 'ed', 'in', 'th', 'la', 'te', 'id', 'an', 'os', 'aa', 'aa', 'aa', 'aa']
# ['thon', 'concei', 'the', 'late', 'ido', 'oss', 'aaaaaa']
# ['thon', 'concei', 'late', 'aaaaaaaa']

# %% [markdown]
# ![image.png](attachment:a4647604-6d07-47cd-a83f-ca2201d66500.png)

# %%
import  re
pattern = re.compile(r"\d+")
result1 = pattern.findall(r"1hello 123456 789")
result2 =pattern.findall(r"one1two2three3four4")
print(result1)
print(result2)
# Out:
# ['1', '123456', '789']
# ['1', '2', '3', '4']

# %%
import re
str1="abc1d abcdd abc2b abc aaaa"
print(re.findall(r"abcd?",str1))
print(re.findall(r"abcd*",str1))
print(re.findall(r"abcd+",str1))
# Out:
# ['abc1', 'abc', 'abc2', 'abc']
# ['abc', 'abcdd', 'abc', 'abc']
# ['abcdd']

# %% [markdown]
# ## split 方法
# + split 方法能以比對規則針對字串進行切割後產生 list。
# + split 它的使用形式如下：
# + split(字串,最大分割次數)
#    + 若不指定最大分割次數則全部分割

# %%
str1 = "ken,vivin,joy"
myList =  str1.split(",")
print(myList)
# Out:
# ['ken', 'vivin', 'joy']

# %%
import re
text = 'one,,,,,     two...ten'
re1 = re.split(r"[,. ]+",text)
print(re1)
# Out:
# ['one', 'two', 'ten']

# %%
str1 = "This is Python.That is Java,This is SQLite"
newStr = str1.replace("is","-")
print(newStr)
# Out:
# Th- - Python.That - Java,Th- - SQLite

# %%
import re
str1 = "This is Python.That is Java,This is SQLite"
rStr = re.sub(r"\bis\b","-",str1)
print(rStr)
# Out:
# This - Python.That - Java,This - SQLite

# %% [markdown]
# ## 作業
#
# 設計錢包總金額為 1000 元，
#
# 如果購買商品總金額超過 1000
#
# 會引發一個金額不足的例外 OverflowError
# ![image.png](attachment:def5f14b-0133-4f65-bf3d-f2333d1faf7f.png)

# %% [markdown]
# ## 物件導向入門

# %%
class Employee: #建立類
    pass
emp1 = Employee() #建立物件
emp2 = Employee()
print(emp1)
#print(emp1.name)
#print(emp2.name)

emp1.name = "Ken" #建立屬性
emp1.salary = 50000
emp2.name = "Iris"
emp2.salary = 65000
print("Name:",emp1.name," Salary:",emp1.salary)
print("Name:",emp2.name," Salary:",emp2.salary)
# Out:
# ...
# Name: Ken  Salary: 50000
# Name: Iris  Salary: 65000

# %%
class Employee:
    def __init__(self,name,salary=28000):
        self.name = name#建立屬性
        self.salary = salary
emp1 = Employee("Vivin")        
emp2 = Employee("Iris",58000)
print(emp1.name,emp1.salary)
print(emp2.name,emp2.salary)
# Out:
# Vivin 28000
# Iris 58000

# %%
class Employee:
    def __init__(self,name,salary=28000):
        self.name = name#建立屬性
        self.salary = salary
    def printInfo(self):
        print("Name:",self.name," Salary:",self.salary)
emp1 = Employee("Vivin")        
emp2 = Employee("Iris",58000)
emp1.printInfo()
emp2.printInfo()
# Out:
# Name: Vivin  Salary: 28000
# Name: Iris  Salary: 58000

# %%
#學生的類別
class Student:
    def __init__(self,name):
        self.scores = [] 
        self.name = name
    def appendScore(self,score):    
        self.scores.append(score)
    def getTotal(self):
        result = 0
        for s in self.scores:
            result += s
        return result
    def printInfo(self):    
        print(f"Name:{self.name} Total:{self.getTotal()}")
st1 = Student("Ken")        
st1.appendScore(80)
st1.appendScore(95)
st1.appendScore(77)

st2 = Student("Vivin")  
st2.appendScore(63)
st2.appendScore(82)
st2.appendScore(97)
st2.appendScore(61)

st1.printInfo()
st2.printInfo()
## 每位學生都有多筆成績scores
## 希望可以附加多筆成績
## 我的printInfo 可顯示 學生姓名 與成績的總和
# Out:
# Name:Ken Total:252
# Name:Vivin Total:303

# %%
class Person:
    company = ""#共用
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def printInfo(self):    
        print(Person.company,self.name,self.age)
Person.company="GJ"        
p1 = Person("Kne",25)        
p2 = Person("Lucy",32)  
p2.age = 28
p1.printInfo()
p2.printInfo()
# Out:
# GJ Kne 25
# GJ Lucy 28

# %% [markdown]
# ## 私有化

# %%
class Animal:
    def __init__(self,name,age):
        self.name = name
        self.setAge(age) ##私有化
    def setAge(self,age):
        if age < 0 or age > 200:
            raise OverflowError(f"錯誤的年齡:{age}")
        self.__age = age
    def getAge(self):    
        return self.age
    def printInfo(self):        
        print(self.name,self.__age)
a1 = Animal("Bobo",5)    
a2 = Animal("Lulu",-2)    
a1.setAge(10)
a1.printInfo()
a2.printInfo()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[97], line 14
#      12         print(self.name,self.__age)
#      13 a1 = Animal("Bobo",5)
# ---> 14 a2 = Animal("Lulu",-2)
#      15 a1.setAge(10)
#      16 a1.printInfo()
#
# Cell In[97], line 4, in Animal.__init__(self, name, age)
#       2 def __init__(self,name,age):
#       3     self.name = name
# ----> 4     self.setAge(age)
#
# Cell In[97], line 7, in Animal.setAge(self, age)
#       5 def setAge(self,age):
#       6     if age < 0 or age > 200:
# ----> 7         raise OverflowError(f"錯誤的年齡:{age}")
#       8     self.__age = age
#
# OverflowError: 錯誤的年齡:-2

# %%
class Employee:
    def __init__(self,name,salary):
        self.__name = name
        self.__salary = salary
    def setName(self,name):
        if len(name) < 2:
            raise Exception("錯誤的姓名"+name)
        self.__name = name
    def getName(self):    
        return self.__name
    def printInfo(self):    
        print(self.__name,self.__salary)
    ##getter
    #@特別的註記
    @property
    def name(self): 
        return self.getName()
    @name.setter      
    def name(self,name):
        self.setName(name)
emp1 = Employee("Ken",26000)
emp1.setName("Iris")
emp1.name = "g"
print(emp1.name )
emp1.printInfo()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[113], line 23
#      21 emp1 = Employee("Ken",26000)
#      22 emp1.setName("Iris")
# ---> 23 emp1.name = "g"
#      24 print(emp1.name )
#      25 emp1.printInfo()
#
# Cell In[113], line 20, in Employee.name(self, name)
#      18 @name.setter
#      19 def name(self,name):
# ---> 20     self.setName(name)
#
# Cell In[113], line 7, in Employee.setName(self, name)
#       5 def setName(self,name):
#       6     if len(name) < 2:
# ----> 7         raise Exception("錯誤的姓名"+name)
#       8     self.__name = name
#
# Exception: 錯誤的姓名g

# %%
class Animal:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def printInfo(self):      
        print(self.name,self.age)
an1 = Animal("Bobo",5)        
an1.printInfo()
# Out:
# Bobo 5

# %%
class Cat(Animal):
    pass
cat1 = Cat("Kitty",10)    
cat1.printInfo()
# Out:
# Kitty 10

# %% [markdown]
# ## 多重繼承與初始化方法
# ### 多重繼承
# + 繼承多個父類別時用，隔開
# + 注意成員搜尋的順序
#   + 從子類別開始
#   + 同一階層父類別由左至右搜尋
#   + 更上層祖父類別由左至右搜尋
#   + 直到達到頂層為止

# %%
class S():
    def method1(self):
        print("S.method1")
    def method2(self):
        print("S.method2")
class Z():
    def method1(self):
         print("Z.method1")
class A(S):
    def method3(self):
        print("A.method3")
class B(Z,S):
    def method2(self):
        print("B.method2")  
    def method3(self):
        print("B.method3")
class C(A,B):
    def method4(self):
        print("C.method4")
c = C()
print(C.mro())#這規則稱為MRO (Method Resolution Order) 
c.method4()
c.method3()
c.method2()
c.method1()
# Out:
# [<class '__main__.C'>, <class '__main__.A'>, <class '__main__.B'>, <class '__main__.Z'>, <class '__main__.S'>, <class 'object'>]
# C.method4
# A.method3
# B.method2
# Z.method1

# %%
class Point:
    def __init__(self,x = 0, y = 0):
        self.x = x
        self.y = y
p1 = Point(2,3)
p2 = Point(-1,2)
print(p1)#(2,3)
print(p2)#(-1,2)

# %%
class Point:
    def __init__(self,x = 0, y = 0):
        self.x = x
        self.y = y
    def __str__(self):    
        return f"({self.x},{self.y})"
p1 = Point(2,3)
p2 = Point(-1,2)
print(p1)#(2,3)
print(p2)#(-1,2)
# Out:
# (2,3)
# (-1,2)

# %%
class Student:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def __str__(self):    
        return f"name {self.name} age {self.age}"
st1 = Student("Ken",10)        
st2 = Student("Vivin",12)        
print(st1)#name Ken age 10
print(st2)#name Vivin age 12
# Out:
# name Ken age 10
# name Vivin age 12

# %% [markdown]
# ``` python
# __add__  +
#
# __iadd__  +=
#
# __sub__  -
#
# __isub__  -=
#
# __mul__  *
#
# __imul__  *=
#
# __truediv__   /
#
# __itruediv__   /=
#
# __floordiv__  //
#
# __ifloordiv__  //=
#
# __mod__  %
#
# __imod__  %=
#
# __pow__  **
#
# __ipow__  **=
# ```

# %%
class Point:
    def __init__(self,x = 0, y = 0):
        self.x = x
        self.y = y
    def __str__(self):    
        return f"({self.x},{self.y})"
    def __add__(self,other):    
        x = self.x + other.x
        y = self.y + other.y
        return Point(x,y)
p1 = Point(2,3)
p2 = Point(-1,2)
print(p1 + p2)
# Out:
# (1,5)

# %%
class Point:
    def __init__(self,x = 0, y = 0):
        self.x = x
        self.y = y
    def __str__(self):    
        return f"({self.x},{self.y})"
    def __len__(self):     
        return self.x ** 2 + self.y **2
    def __add__(self,other):    
        x = self.x + other.x
        y = self.y + other.y
        return Point(x,y)
p1 = Point(2,3)
p2 = Point(-1,2)
print(p1 + p2)
print(len(p1))
# Out:
# Bye
# (1,5)
# 13
